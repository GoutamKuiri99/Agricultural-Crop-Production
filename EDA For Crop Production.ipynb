# %%
import pandas as pd
import numpy as np

# seaborn
import seaborn as sns

# matplotlib
import matplotlib.pyplot as plt

# %%
a_data=pd.read_csv("Crop Production data.csv")

# %%
a_data.head()
# Out:
#        State_Name District_Name  Crop_Year       Season          Crop  \
# 0  Andhra Pradesh     ANANTAPUR       1997  Kharif          Arhar/Tur
# 1  Andhra Pradesh     ANANTAPUR       1997  Kharif              Bajra
# 2  Andhra Pradesh     ANANTAPUR       1997  Kharif        Castor seed
# 3  Andhra Pradesh     ANANTAPUR       1997  Kharif       Cotton(lint)
# 4  Andhra Pradesh     ANANTAPUR       1997  Kharif       Dry chillies
#
#       Area  Production
# 0  21400.0      2600.0
# 1   1400.0       500.0
# 2   1000.0       100.0
# 3   7300.0      9400.0
# 4   3700.0      7100.0

# %%
a_data.tail()
# Out:
#        State_Name  District_Name  Crop_Year       Season               Crop  \
# 246086     Sikkim  WEST DISTRICT       2015  Kharif                Soyabean
# 246087     Sikkim  WEST DISTRICT       2015  Kharif                    Urad
# 246088     Sikkim  WEST DISTRICT       2015  Rabi                    Barley
# 246089     Sikkim  WEST DISTRICT       2015  Rabi         Rapeseed &Mustard
# 246090     Sikkim  WEST DISTRICT       2015  Rabi                     Wheat
#
#          Area  Production
# 246086  546.0       520.0
# 246087  914.0       811.0
# 246088   12.0        11.0
# 246089  625.0       540.0
# 246090   20.0        21.0

# %%
a_data.describe()
# Out:
#            Crop_Year          Area    Production
# count  246091.000000  2.460910e+05  2.423610e+05
# mean     2005.643018  1.200282e+04  5.825034e+05
# std         4.952164  5.052340e+04  1.706581e+07
# min      1997.000000  4.000000e-02  0.000000e+00
# 25%      2002.000000  8.000000e+01  8.800000e+01
# 50%      2006.000000  5.820000e+02  7.290000e+02
# 75%      2010.000000  4.392000e+03  7.023000e+03
# max      2015.000000  8.580100e+06  1.250800e+09

# %%
a_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246091 entries, 0 to 246090
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   State_Name     246091 non-null  object
#  1   District_Name  246091 non-null  object
#  2   Crop_Year      246091 non-null  int64
#  3   Season         246091 non-null  object
#  4   Crop           246091 non-null  object
#  5   Area           246091 non-null  float64
#  6   Production     242361 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.1+ MB

# %% [markdown]
# # EDA on Agriculture data

# %% [markdown]
# # Plotting categoricals and numericals

# %%
sns.countplot(data = a_data, x = "State_Name")

plt.xticks(rotation = 90)
plt.show()

# %%
a_data.State_Name.value_counts()[:10].plot(kind = "bar")
# Out:
# <Axes: xlabel='State_Name'>

# %%
a_data.	District_Name.value_counts()[:10].plot(kind = "bar")
# Out:
# <Axes: xlabel='District_Name'>

# %%
sns.countplot(data = a_data, x = "Crop")

plt.xticks(rotation = 90)
plt.show()

# %%
a_data.Crop.value_counts()[:10]
# Out:
# Crop
# Rice                 15104
# Maize                13947
# Moong(Green Gram)    10318
# Urad                  9850
# Sesamum               9046
# Groundnut             8834
# Sugarcane             7921
# Wheat                 7899
# Rapeseed &Mustard     7592
# Arhar/Tur             7578
# Name: count, dtype: int64

# %%
a_data.Crop.value_counts()[:10].plot(kind = "bar")
# Out:
# <Axes: xlabel='Crop'>

# %%
a_data.head()
# Out:
#        State_Name District_Name  Crop_Year       Season          Crop  \
# 0  Andhra Pradesh     ANANTAPUR       1997  Kharif          Arhar/Tur
# 1  Andhra Pradesh     ANANTAPUR       1997  Kharif              Bajra
# 2  Andhra Pradesh     ANANTAPUR       1997  Kharif        Castor seed
# 3  Andhra Pradesh     ANANTAPUR       1997  Kharif       Cotton(lint)
# 4  Andhra Pradesh     ANANTAPUR       1997  Kharif       Dry chillies
#
#       Area  Production
# 0  21400.0      2600.0
# 1   1400.0       500.0
# 2   1000.0       100.0
# 3   7300.0      9400.0
# 4   3700.0      7100.0

# %%
sns.countplot(data = a_data, x = "Crop_Year")

plt.xticks(rotation = 90)
plt.show()

# %%
sns.histplot(data = a_data, x = "Production", bins = 10)
plt.show()

# %%
sns.histplot(data = a_data, x = "Area", bins = 10)
plt.show()

# %%
# sns.displot(data = a_data, x = "area")
# plt.show()

# %%
sns.boxplot(data = a_data, x = "Production")
# Out:
# <Axes: xlabel='Production'>

# %%
sns.boxplot(data = a_data, x = "Area")
# Out:
# <Axes: xlabel='Area'>

# %%
a_data.head()
# Out:
#        State_Name District_Name  Crop_Year       Season          Crop  \
# 0  Andhra Pradesh     ANANTAPUR       1997  Kharif          Arhar/Tur
# 1  Andhra Pradesh     ANANTAPUR       1997  Kharif              Bajra
# 2  Andhra Pradesh     ANANTAPUR       1997  Kharif        Castor seed
# 3  Andhra Pradesh     ANANTAPUR       1997  Kharif       Cotton(lint)
# 4  Andhra Pradesh     ANANTAPUR       1997  Kharif       Dry chillies
#
#       Area  Production
# 0  21400.0      2600.0
# 1   1400.0       500.0
# 2   1000.0       100.0
# 3   7300.0      9400.0
# 4   3700.0      7100.0

# %%
# Surprising that Kerala state has highest crop production.
a_data.groupby(["State_Name"]).agg({"Production" : "sum"}).plot(kind = "bar")
# Out:
# <Axes: xlabel='State_Name'>

# %%
a_data.groupby(["Crop"]).agg({"Production" : "sum"}).plot(kind = "bar")
# Out:
# <Axes: xlabel='Crop'>

# %%
a_data.head()
# Out:
#        State_Name District_Name  Crop_Year       Season          Crop  \
# 0  Andhra Pradesh     ANANTAPUR       1997  Kharif          Arhar/Tur
# 1  Andhra Pradesh     ANANTAPUR       1997  Kharif              Bajra
# 2  Andhra Pradesh     ANANTAPUR       1997  Kharif        Castor seed
# 3  Andhra Pradesh     ANANTAPUR       1997  Kharif       Cotton(lint)
# 4  Andhra Pradesh     ANANTAPUR       1997  Kharif       Dry chillies
#
#       Area  Production
# 0  21400.0      2600.0
# 1   1400.0       500.0
# 2   1000.0       100.0
# 3   7300.0      9400.0
# 4   3700.0      7100.0

# %%
a_data.groupby(["Crop_Year"]).agg({"Production" : "sum"}).plot(kind = "bar")
# Out:
# <Axes: xlabel='Crop_Year'>

# %%
a_data.groupby(["Season"]).agg({"Production" : "sum"}).plot(kind = "bar")
# Out:
# <Axes: xlabel='Season'>
